# %% [markdown]
# <img src="BL.png">
# # Training und Test eines Support Vector Classifiers mit scikit-learn für Profifußballer

# %%
#PANDAS FÜR TRANSFORMATION DER DATEN
import pandas as pd
import numpy as np
import time as t
#IMPORT UND LÖSCHEN DES AUTOMATISCH NEU ANGELEGTEN INDEX'
X = pd.read_csv('X.csv')
y = pd.read_csv('y.csv').drop('Unnamed: 0', axis=1)
player_info = pd.read_csv('player_info.csv', encoding = "ISO-8859-1")
X = X.drop('Unnamed: 0', axis=1)

X.join(player_info, how='left')
# Out:
#        height_cm  weight_kg  overall  pac  sho  pas  dri  def  phy  crossing  \
# 0          185.0       80.0       94   90   93   82   90   33   80        85
# 1          170.0       72.0       93   89   90   86   96   26   61        77
# 2          175.0       68.0       92   92   84   79   95   30   60        75
# 3          182.0       86.0       92   82   90   79   87   42   81        77
# 4          193.0       92.0       92   91   90   95   89   60   91        15
# 5          185.0       79.0       91   81   88   75   86   38   82        62
# 6          193.0       76.0       90   90   85   87   90   58   86        17
# 7          173.0       76.0       90   90   82   84   92   32   66        80
# 8          182.0       78.0       90   56   81   89   81   73   70        85
# 9          184.0       87.0       90   79   87   70   83   25   74        68
# 10         183.0       75.0       90   76   63   71   71   88   83        66
# 11         181.0       68.0       89   75   84   88   85   45   75        90
# 12         199.0       94.0       89   85   91   69   88   49   86        14
# 13         169.0       62.0       89   86   84   80   89   40   78        80
# 14         174.0       65.0       89   73   75   86   89   72   65        78
# 15         183.0       74.0       89   94   87   84   85   57   76        87
# 16         173.0       70.0       89   87   88   75   89   23   72        70
# 17         187.0       85.0       89   74   46   56   59   90   85        58
# 18         191.0       94.0       89   89   88   74   84   46   90        13
# 19         177.0       73.0       88   86   85   81   91   24   67        80
# 20         189.0       82.0       88   84   90   77   84   52   87        13
# 21         174.0       72.0       88   86   85   78   87   30   68        82
# 22         174.0       70.0       88   72   75   85   90   62   63        72
# 23         187.0       80.0       88   96   84   75   81   37   71        77
# 24         190.0       85.0       88   68   54   70   70   87   81        44
# 25         192.0       90.0       88   75   50   72   67   88   84        69
# 26         186.0       78.0       88   67   48   65   63   88   79        55
# 27         191.0       92.0       88   64   58   75   71   89   76        64
# 28         180.0       76.0       88   71   74   87   86   24   58        82
# 29         188.0       82.0       88   88   86   68   90   64   82        13
# ...          ...        ...      ...  ...  ...  ...  ...  ...  ...       ...
# 17964      173.0       68.0       48   62   43   43   49   25   45        50
# 17965      178.0       70.0       48   67   50   40   52   22   37        48
# 17966      178.0       64.0       48   54   37   47   52   45   51        36
# 17967      181.0       80.0       48   58   26   28   32   46   57        24
# 17968      175.0       68.0       47   54   24   39   43   45   45        39
# 17969      180.0       68.0       47   58   26   34   31   47   52        37
# 17970      177.0       70.0       47   68   43   44   46   32   58        34
# 17971      178.0       70.0       47   53   32   46   45   46   49        32
# 17972      180.0       72.0       47   53   32   46   45   44   49        31
# 17973      175.0       67.0       47   61   37   44   47   41   44        34
# 17974      171.0       66.0       47   58   32   46   49   45   44        31
# 17975      180.0       75.0       47   58   24   34   49   44   60        47
# 17976      180.0       73.0       47   59   23   26   32   46   53        25
# 17977      172.0       65.0       47   64   48   38   52   17   43        32
# 17978      185.0       74.0       47   45   43   43   48   40   45        49
# 17979      178.0       75.0       47   54   28   34   38   41   64        29
# 17980      175.0       80.0       47   54   55   39   48   19   53        28
# 17981      177.0       72.0       47   59   38   42   42   46   49        51
# 17982      180.0       68.0       46   67   38   42   46   39   52        34
# 17983      176.0       69.0       46   56   28   30   44   46   46        36
# 17984      170.0       64.0       46   64   37   42   47   39   45        36
# 17985      172.0       66.0       46   63   20   29   34   46   45        28
# 17986      195.0       86.0       46   48   39   46   53   40   42         9
# 17987      183.0       64.0       46   57   26   26   30   46   47        27
# 17988      173.0       75.0       46   23   42   48   45   36   38        42
# 17989      188.0       74.0       46   46   47   49   48   28   42        14
# 17990      185.0       77.0       46   39   50   39   37   25   50        11
# 17991      175.0       71.0       46   58   47   35   43   20   33        28
# 17992      176.0       61.0       46   58   35   44   45   45   47        34
# 17993      182.0       72.0       46   49   20   24   30   41   61        19
#
#                    ...                penalties  composure  marking  \
# 0                  ...                       85         95       22
# 1                  ...                       78         96       13
# 2                  ...                       81         92       21
# 3                  ...                       85         83       30
# 4                  ...                       47         70       10
# 5                  ...                       84         87       25
# 6                  ...                       40         64       13
# 7                  ...                       86         87       25
# 8                  ...                       73         85       63
# 9                  ...                       70         86       12
# 10                 ...                       68         80       86
# 11                 ...                       77         84       30
# 12                 ...                       27         52       11
# 13                 ...                       77         86       30
# 14                 ...                       80         84       66
# 15                 ...                       76         85       51
# 16                 ...                       83         90       13
# 17                 ...                       50         82       92
# 18                 ...                       22         70       10
# 19                 ...                       86         84       14
# 20                 ...                       11         55       14
# 21                 ...                       71         86       23
# 22                 ...                       75         83       49
# 23                 ...                       74         84       28
# 24                 ...                       70         84       84
# 25                 ...                       46         86       88
# 26                 ...                       50         82       87
# 27                 ...                       68         91       85
# 28                 ...                       67         78       22
# 29                 ...                       40         61       12
# ...                ...                      ...        ...      ...
# 17964              ...                       52         38       21
# 17965              ...                       45         44       16
# 17966              ...                       39         46       44
# 17967              ...                       38         40       40
# 17968              ...                       31         42       42
# 17969              ...                       30         35       45
# 17970              ...                       39         47       22
# 17971              ...                       35         39       48
# 17972              ...                       40         35       37
# 17973              ...                       39         38       39
# 17974              ...                       44         35       44
# 17975              ...                       35         38       38
# 17976              ...                       36         48       37
# 17977              ...                       48         42       12
# 17978              ...                       48         30       23
# 17979              ...                       35         38       41
# 17980              ...                       63         44       15
# 17981              ...                       36         43       49
# 17982              ...                       24         50       36
# 17983              ...                       33         38       42
# 17984              ...                       31         35       35
# 17985              ...                       25         37       40
# 17986              ...                       24         23        9
# 17987              ...                       35         38       37
# 17988              ...                       41         42       37
# 17989              ...                       17         23        9
# 17990              ...                       22         44       14
# 17991              ...                       58         50       18
# 17992              ...                       43         45       43
# 17993              ...                       21         33       38
#
#        standing_tackle  Unnamed: 0  index                     full_name  \
# 0                   31           0      0  C. Ronaldo dos Santos Aveiro
# 1                   28           1      1                  Lionel Messi
# 2                   24           2      2    Neymar da Silva Santos Jr.
# 3                   45           3      3                   Luis Suárez
# 4                   10           4      4                  Manuel Neuer
# 5                   42           5      5            Robert Lewandowski
# 6                   21           6      6         David De Gea Quintana
# 7                   27           7      7                   Eden Hazard
# 8                   82           8      8                    Toni Kroos
# 9                   22           9      9               Gonzalo Higuaín
# 10                  89          10     10           Sergio Ramos García
# 11                  51          11     11               Kevin De Bruyne
# 12                  18          12     12              Thibaut Courtois
# 13                  39          13     13                Alexis Sánchez
# 14                  80          14     14                   Luka Modri?
# 15                  55          15     15                   Gareth Bale
# 16                  20          16     16                 Sergio Agüero
# 17                  92          17     17             Giorgio Chiellini
# 18                  11          18     18              Gianluigi Buffon
# 19                  20          19     19                  Paulo Dybala
# 20                  12          20     20                     Jan Oblak
# 21                  22          21     21             Antoine Griezmann
# 22                  64          22     22              Thiago Alcântara
# 23                  25          23     23     Pierre-Emerick Aubameyang
# 24                  88          24     24              Leonardo Bonucci
# 25                  91          25     25                Jérôme Boateng
# 26                  86          26     26                   Diego Godín
# 27                  92          27     27                  Mats Hummels
# 28                  16          28     28                    Mesut Özil
# 29                  10          29     29                   Hugo Lloris
# ...                ...         ...    ...                           ...
# 17964               25       17964  17964               Tyrell Robinson
# 17965               23       17965  17965                 Darren Clarke
# 17966               44       17966  17966                  Ronan Hughes
# 17967               52       17967  17967                 Zehn Mohammed
# 17968               46       17968  17968               Dominic Peppard
# 17969               48       17969  17969                 Calvin Rogers
# 17970               33       17970  17970               Neil McLaughlin
# 17971               45       17971  17971                  Garan Manley
# 17972               44       17972  17972               Pierce Phillips
# 17973               44       17973  17973                    Alec Byrne
# 17974               44       17974  17974               Kotaro Fujikawa
# 17975               46       17975  17975                     Kyle Egan
# 17976               51       17976  17976              Tyler Brownsword
# 17977               20       17977  17977               Florian Prohart
# 17978               21       17978  17978                   Louis Jones
# 17979               46       17979  17979                 Alfie Kilgour
# 17980               13       17980  17980                    Ryan White
# 17981               48       17981  17981                  Aaron Conway
# 17982               44       17982  17982                 Harry Clifton
# 17983               48       17983  17983                  Mikey Whelan
# 17984               39       17984  17984                    Tom Sawyer
# 17985               52       17985  17985                   Jack Keeble
# 17986                9       17986  17986             Kai McKenzie-Lyle
# 17987               54       17987  17987                 Nathan Sheron
# 17988               36       17988  17988               Tommy Käßemodel
# 17989               11       17989  17989                   Adam Kelsey
# 17990               12       17990  17990              Barry Richardson
# 17991               17       17991  17991                  Jordan Young
# 17992               48       17992  17992                Josh Lundstram
# 17993               44       17993  17993                 Leslie Sackey
#
#                          club  age                         league
# 0              Real Madrid CF   32       Spanish Primera División
# 1                FC Barcelona   30       Spanish Primera División
# 2         Paris Saint-Germain   25                 French Ligue 1
# 3                FC Barcelona   30       Spanish Primera División
# 4            FC Bayern Munich   31              German Bundesliga
# 5            FC Bayern Munich   28              German Bundesliga
# 6           Manchester United   26         English Premier League
# 7                     Chelsea   26         English Premier League
# 8              Real Madrid CF   27       Spanish Primera División
# 9                    Juventus   29                Italian Serie A
# 10             Real Madrid CF   31       Spanish Primera División
# 11            Manchester City   26         English Premier League
# 12                    Chelsea   25         English Premier League
# 13                    Arsenal   28         English Premier League
# 14             Real Madrid CF   31       Spanish Primera División
# 15             Real Madrid CF   27       Spanish Primera División
# 16            Manchester City   29         English Premier League
# 17                   Juventus   32                Italian Serie A
# 18                   Juventus   39                Italian Serie A
# 19                   Juventus   23                Italian Serie A
# 20            Atlético Madrid   24       Spanish Primera División
# 21            Atlético Madrid   26       Spanish Primera División
# 22           FC Bayern Munich   26              German Bundesliga
# 23          Borussia Dortmund   28              German Bundesliga
# 24                      Milan   30                Italian Serie A
# 25           FC Bayern Munich   28              German Bundesliga
# 26            Atlético Madrid   31       Spanish Primera División
# 27           FC Bayern Munich   28              German Bundesliga
# 28                    Arsenal   28         English Premier League
# 29          Tottenham Hotspur   30         English Premier League
# ...                       ...  ...                            ...
# 17964           Bradford City   19             English League One
# 17965         Shamrock Rovers   20  Rep. Ireland Premier Division
# 17966  Hamilton Academical FC   18           Scottish Premiership
# 17967      Accrington Stanley   17             English League Two
# 17968             Bohemian FC   17  Rep. Ireland Premier Division
# 17969          Bray Wanderers   17  Rep. Ireland Premier Division
# 17970    Partick Thistle F.C.   18           Scottish Premiership
# 17971               Cork City   19  Rep. Ireland Premier Division
# 17972               Cork City   18  Rep. Ireland Premier Division
# 17973               Cork City   18  Rep. Ireland Premier Division
# 17974            Júbilo Iwata   18             Japanese J1 League
# 17975             Exeter City   19             English League Two
# 17976               Morecambe   17             English League Two
# 17977          Wolfsberger AC   18            Austrian Bundesliga
# 17978        Doncaster Rovers   18             English League One
# 17979          Bristol Rovers   19             English League One
# 17980        Bolton Wanderers   18           English Championship
# 17981           Galway United   19  Rep. Ireland Premier Division
# 17982            Grimsby Town   19             English League Two
# 17983           Galway United   18  Rep. Ireland Premier Division
# 17984            Grimsby Town   18             English League Two
# 17985            Grimsby Town   18             English League Two
# 17986                  Barnet   19             English League Two
# 17987          Fleetwood Town   19             English League One
# 17988       FC Erzgebirge Aue   28           German 2. Bundesliga
# 17989       Scunthorpe United   17             English League One
# 17990       Wycombe Wanderers   47             English League Two
# 17991            Swindon Town   17             English League Two
# 17992         Crewe Alexandra   18             English League Two
# 17993       Scunthorpe United   18             English League One
#
# [17994 rows x 41 columns]

# %%
col_names = list(X.columns.values)

X.describe()
# Out:
#           height_cm     weight_kg       overall           pac           sho  \
# count  17994.000000  17994.000000  17994.000000  17994.000000  17994.000000
# mean     181.271980     75.400856     66.253029     67.739969     53.485217
# std        6.690392      6.994824      6.946729     10.937646     13.833779
# min      155.000000     49.000000     46.000000     21.000000     14.000000
# 25%      177.000000     70.000000     62.000000     61.000000     44.000000
# 50%      181.000000     75.000000     66.000000     68.000000     56.000000
# 75%      186.000000     80.000000     71.000000     75.000000     64.000000
# max      205.000000    110.000000     94.000000     96.000000     93.000000
#
#                 pas           dri           def           phy      crossing  \
# count  17994.000000  17994.000000  17994.000000  17994.000000  17994.000000
# mean      57.531177     62.591308     49.404301     64.767033     49.806046
# std       10.466810     10.377375     17.120189      9.657583     18.436764
# min       24.000000     24.000000     12.000000     27.000000      5.000000
# 25%       51.000000     57.000000     34.000000     58.000000     38.000000
# 50%       58.000000     64.000000     52.000000     66.000000     54.000000
# 75%       65.000000     70.000000     64.000000     72.000000     64.000000
# max       95.000000     96.000000     90.000000     92.000000     90.000000
#
#             ...              jumping    long_shots    aggression  \
# count       ...         17994.000000  17994.000000  17994.000000
# mean        ...            64.885351     47.238691     55.828109
# std         ...            11.878768     19.267705     17.455601
# min         ...            13.000000      3.000000     11.000000
# 25%         ...            58.000000     33.000000     43.000000
# 50%         ...            66.000000     51.000000     59.000000
# 75%         ...            73.000000     63.000000     69.000000
# max         ...            95.000000     92.000000     96.000000
#
#        interceptions   positioning        vision     penalties     composure  \
# count   17994.000000  17994.000000  17994.000000  17994.000000  17994.000000
# mean       46.575247     49.681060     53.030788     48.989163     57.886684
# std        20.684196     19.413951     14.358107     15.802867     12.905050
# min         4.000000      2.000000     10.000000      5.000000      5.000000
# 25%        26.000000     38.000000     43.000000     39.000000     51.000000
# 50%        52.000000     55.000000     55.000000     50.000000     60.000000
# 75%        64.000000     64.000000     64.000000     61.000000     67.000000
# max        92.000000     95.000000     94.000000     92.000000     96.000000
#
#             marking  standing_tackle
# count  17994.000000     17994.000000
# mean      44.124986        47.478937
# std       21.582512        21.819514
# min        4.000000         4.000000
# 25%       22.000000        26.000000
# 50%       48.000000        54.000000
# 75%       63.000000        66.000000
# max       92.000000        92.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# ## Standardisieren der Daten
# Um das Training von verschiedenen Wertebereichen der Features unabhängig zu machen, standardisieren wir jede Spalte (z.B. "height_cm" aus [150,210] und "dri" aus [0.3,1.0] -> das Feature "height_cm" wird stärker gewichtet).<br><br>
# Sei $C$ eine Spalte der Länge $n$, dann kann man die Werte in der Spalte als Ausgang eines $n$-fach wiederholten Zufallsexperiments auffassen. Sei $X$ diejenige Zufallsvariable, die die einfache Ausführung des Zufallsexperiments beschreibt.<br>
#
# Wir standardisieren nun alle $x\in C$ durch:<br>
# $ x_{std}=\frac{x - \mathbb{E}(X)}{\sqrt{Var(X)}}$
# <br>
#
# Beim Standardisieren handelt es sich um einen Isomorphismus, und<br>
# $X\sim\sigma(a,b) \Rightarrow X_{std}  \sim\sigma(0,1)$

# %%
#SKALIEREN DER DATEN

from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
sc_X = sc_X.fit(X)

X = sc_X.transform(X)

X = pd.DataFrame(X)
X.columns=col_names

X.describe()
# Out:
#           height_cm     weight_kg       overall           pac           sho  \
# count  1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04
# mean  -1.227506e-15 -1.774635e-15 -1.379118e-13  3.577406e-15 -6.445587e-15
# std    1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min   -3.926931e+00 -3.774447e+00 -2.915558e+00 -4.273430e+00 -2.854340e+00
# 25%   -6.385423e-01 -7.721432e-01 -6.122518e-01 -6.162346e-01 -6.856753e-01
# 50%   -4.065339e-02 -5.730909e-02 -3.642518e-02  2.377462e-02  1.817907e-01
# 75%    7.067077e-01  6.575250e-01  6.833581e-01  6.637839e-01  7.601014e-01
# max    3.546680e+00  4.946530e+00  3.994361e+00  2.583812e+00  2.856478e+00
#
#                 pas           dri           def           phy      crossing  \
# count  1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04
# mean   1.218582e-14 -1.563162e-14 -2.736625e-15 -8.367842e-15  2.965876e-15
# std    1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min   -3.203661e+00 -3.718896e+00 -2.184867e+00 -3.910718e+00 -2.430323e+00
# 25%   -6.240066e-01 -5.388129e-01 -8.997991e-01 -7.007159e-01 -6.403713e-01
# 50%    4.479263e-02  1.357502e-01  1.516205e-01  1.276718e-01  2.274841e-01
# 75%    7.135919e-01  7.139472e-01  8.525668e-01  7.489625e-01  7.698937e-01
# max    3.579874e+00  3.219467e+00  2.371284e+00  2.819932e+00  2.180159e+00
#
#             ...              jumping    long_shots    aggression  \
# count       ...         1.799400e+04  1.799400e+04  1.799400e+04
# mean        ...        -1.739081e-15  1.536814e-16 -4.398697e-15
# std         ...         1.000028e+00  1.000028e+00  1.000028e+00
# min         ...        -4.368028e+00 -2.296066e+00 -2.568193e+00
# 25%         ...        -5.796512e-01 -7.390131e-01 -7.349197e-01
# 50%         ...         9.383804e-02  1.952186e-01  1.817170e-01
# 75%         ...         6.831411e-01  8.180397e-01  7.546149e-01
# max         ...         2.535237e+00  2.323191e+00  2.301439e+00
#
#        interceptions   positioning        vision     penalties     composure  \
# count   1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04  1.799400e+04
# mean   -7.484535e-16 -3.740071e-15  1.014095e-15 -1.547673e-16  6.615767e-15
# std     1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00  1.000028e+00
# min    -2.058404e+00 -2.456089e+00 -2.997051e+00 -2.783696e+00 -4.098253e+00
# 25%    -9.947604e-01 -6.017005e-01 -6.986344e-01 -6.321284e-01 -5.336574e-01
# 50%     2.622729e-01  2.739827e-01  1.371536e-01  6.396719e-02  1.637634e-01
# 75%     8.424421e-01  7.375798e-01  7.639947e-01  7.600628e-01  7.062017e-01
# max     2.196170e+00  2.334414e+00  2.853465e+00  2.721787e+00  2.953446e+00
#
#             marking  standing_tackle
# count  1.799400e+04     1.799400e+04
# mean  -3.485813e-15     1.795007e-15
# std    1.000028e+00     1.000028e+00
# min   -1.859195e+00    -1.992718e+00
# 25%   -1.025163e+00    -9.844186e-01
# 50%    1.795491e-01     2.988721e-01
# 75%    8.745756e-01     8.488538e-01
# max    2.218293e+00     2.040481e+00
#
# [8 rows x 35 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.1)

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf')
start = t.time()
svc = svc.fit(X_train,y_train)
end = t.time()
print('Das Training hat',float(end-start),'Sekunden gedauert.')
y_pred = svc.predict(X_test)
print('Precision in sample :{}% \n Precision in test: {}%'.format(100*svc.score(X_train,y_train),100*svc.score(X_test,y_test)))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Mittelfeld       0.85      0.81      0.83       412
#        Sturm       0.92      0.94      0.93       544
#      Torwart       1.00      1.00      1.00       214
# Verteidigung       0.94      0.95      0.94       630
#
#  avg / total       0.92      0.92      0.92      1800

# %%
#Reduziere Feature-Anzahl auf 8 (statt 36).

#X_train_modif = X_train_modif.join(y_train)
from sklearn.decomposition import PCA
pca = PCA(n_components= 3)
X_pca = pca.fit_transform(X)
X_pca = pd.DataFrame(X_pca, index=X.index, columns=['PC1','PC2','PC3'])

#VERSCHLECHTERT PERFORMANCE, WARUM?: Scale X_pca
#sc_X = StandardScaler().fit(X_pca)
#X_pca = sc_X.transform(X_pca)

X_pca_train,X_pca_test,y_pca_train,y_pca_test = train_test_split(X_pca,y, test_size=0.1)

svc_pca = SVC(kernel='rbf')
start = t.time()
svc_pca = svc_pca.fit(X_pca_train,y_pca_train)
end = t.time()
y_pred_pca = svc_pca.predict(X_pca_test)
print('Das Training hat',end-start,'Sekunden gedauert.')
print('Precision in sample :{}% \n Precision in test: {}%'.format(100*svc_pca.score(X_pca_train,y_pca_train),100*svc_pca.score(X_pca_test,y_pca_test)))

# %%
print(classification_report(y_pca_test, y_pred_pca))
# Out:
#               precision    recall  f1-score   support
#
#   Mittelfeld       0.69      0.52      0.60       437
#        Sturm       0.81      0.90      0.85       539
#      Torwart       1.00      0.99      1.00       194
# Verteidigung       0.86      0.92      0.89       630
#
#  avg / total       0.82      0.83      0.82      1800

# %%
from sklearn.cluster import KMeans
k_means = KMeans(n_clusters=4)
k_means = k_means.fit(X_pca)
y_k_means = k_means.predict(X_pca)
y_k_means = pd.DataFrame(y_k_means, columns=['k_means_result'], index=X_pca.index) 
y_k_means
y_test_1 = y.join(y_k_means, how='left')
y_test_1.groupby(['Position','k_means_result']).size()
# Out:
# Position      k_means_result
# Mittelfeld    0                 1108
#               2                 2363
#               3                  665
# Sturm         0                 3512
#               1                    3
#               2                 2247
#               3                   81
# Torwart       1                 2021
# Verteidigung  0                  301
#               1                    2
#               2                 1425
#               3                 4266
# dtype: int64

# %%
k_means_stats = pd.DataFrame(k_means.predict(X_pca), index=X_pca.index, columns=['k-means Cluster Number'])
def join_cluster_center(x):
    return k_means.cluster_centers_[x]
k_means_stats['Cluster Center'] = k_means_stats['k-means Cluster Number'].apply(join_cluster_center)
k_means_stats = k_means_stats.join(y,how='left')
k_means_stats = k_means_stats.join(X_pca, how='left')
k_means_stats_0=k_means_stats.where(k_means_stats['k-means Cluster Number']==0).dropna()
k_means_stats_0=np.array(k_means_stats_0[['PC1','PC2','PC3']])
k_means_stats_1=k_means_stats.where(k_means_stats['k-means Cluster Number']==1).dropna()
k_means_stats_1=np.array(k_means_stats_1[['PC1','PC2','PC3']])
k_means_stats_2=k_means_stats.where(k_means_stats['k-means Cluster Number']==2).dropna()
k_means_stats_2=np.array(k_means_stats_2[['PC1','PC2','PC3']])
k_means_stats_3=k_means_stats.where(k_means_stats['k-means Cluster Number']==3).dropna()
k_means_stats_3=np.array(k_means_stats_3[['PC1','PC2','PC3']])
#PCA_Datapoints = np.array(k_means_stats[['PC1','PC2','PC3']])
#k_means_stats['PCA Datapoints']=PCA_Datapoints.tolist()
#k_means_stats
#x_dp, y_dp, z_dp = PCA_Datapoints.T
k_means_stats

#def calc_dist(x):
# Out:
#        k-means Cluster Number  \
# 0                           3
# 1                           3
# 2                           3
# 3                           3
# 4                           0
# 5                           3
# 6                           0
# 7                           3
# 8                           3
# 9                           3
# 10                          3
# 11                          3
# 12                          0
# 13                          3
# 14                          3
# 15                          3
# 16                          3
# 17                          3
# 18                          0
# 19                          3
# 20                          0
# 21                          3
# 22                          3
# 23                          3
# 24                          3
# 25                          3
# 26                          3
# 27                          3
# 28                          3
# 29                          0
# ...                       ...
# 17964                       1
# 17965                       1
# 17966                       2
# 17967                       2
# 17968                       2
# 17969                       2
# 17970                       1
# 17971                       2
# 17972                       2
# 17973                       1
# 17974                       2
# 17975                       2
# 17976                       2
# 17977                       1
# 17978                       0
# 17979                       2
# 17980                       1
# 17981                       2
# 17982                       1
# 17983                       2
# 17984                       1
# 17985                       2
# 17986                       0
# 17987                       2
# 17988                       2
# 17989                       0
# 17990                       0
# 17991                       1
# 17992                       2
# 17993                       0
#
#                                           Cluster Center      Position  \
# 0       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 1       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 2       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 3       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 4         [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 5       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 6         [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 7       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 8       [-3.69602395073, 0.285856429287, 0.893462621406]    Mittelfeld
# 9       [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 10      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 11      [-3.69602395073, 0.285856429287, 0.893462621406]    Mittelfeld
# 12        [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 13      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 14      [-3.69602395073, 0.285856429287, 0.893462621406]    Mittelfeld
# 15      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 16      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 17      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 18        [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 19      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 20        [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 21      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 22      [-3.69602395073, 0.285856429287, 0.893462621406]    Mittelfeld
# 23      [-3.69602395073, 0.285856429287, 0.893462621406]         Sturm
# 24      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 25      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 26      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 27      [-3.69602395073, 0.285856429287, 0.893462621406]  Verteidigung
# 28      [-3.69602395073, 0.285856429287, 0.893462621406]    Mittelfeld
# 29        [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# ...                                                  ...           ...
# 17964  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17965  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17966    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17967    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17968    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17969    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17970  [-0.675991647756, -2.22149946692, -1.11284438286]    Mittelfeld
# 17971    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17972    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17973  [-0.675991647756, -2.22149946692, -1.11284438286]    Mittelfeld
# 17974    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17975    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17976    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17977  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17978     [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 17979    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17980  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17981    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17982  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17983    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17984  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17985    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17986     [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 17987    [1.81904509191, 2.60651710307, -0.952801411433]  Verteidigung
# 17988    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17989     [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 17990     [8.17142934436, -1.92708527453, 2.38365561251]       Torwart
# 17991  [-0.675991647756, -2.22149946692, -1.11284438286]         Sturm
# 17992    [1.81904509191, 2.60651710307, -0.952801411433]    Mittelfeld
# 17993     [8.17142934436, -1.92708527453, 2.38365561251]  Verteidigung
#
#              PC1       PC2       PC3
# 0     -10.095852 -1.894058  5.539270
# 1     -10.643740 -4.259971  3.726931
# 2      -9.460508 -3.888015  2.915658
# 3      -9.034861 -1.103689  5.391504
# 4       2.701774 -0.699508  7.936001
# 5      -8.721517 -0.994041  4.762926
# 6       2.796645 -1.028414  6.526489
# 7      -9.356940 -3.411701  3.070152
# 8      -8.030161  1.415553  4.693369
# 9      -6.926319 -2.513413  4.894180
# 10     -6.245626  4.441020  2.509148
# 11     -8.963699 -1.197423  4.080162
# 12      5.547783 -1.555484  7.005652
# 13     -9.523186 -1.981392  2.572973
# 14     -9.152919  0.325315  2.246522
# 15     -9.618016 -0.225289  3.682616
# 16     -8.961693 -3.721664  3.282576
# 17     -2.425036  6.030435  1.913875
# 18      4.585541 -1.050658  6.903851
# 19     -9.084347 -3.981818  3.388563
# 20      5.350772 -1.575913  6.094304
# 21     -8.960293 -2.633749  3.139663
# 22     -8.962348 -0.304463  2.604692
# 23     -7.853265 -2.268080  3.724562
# 24     -4.578494  5.377587  3.673434
# 25     -4.017770  5.478440  3.389158
# 26     -3.365897  5.688211  2.135149
# 27     -4.991622  4.881442  4.061903
# 28     -7.245196 -3.302507  4.023996
# 29      4.300948 -1.239377  5.204812
# ...          ...       ...       ...
# 17964   3.366088 -3.504238 -4.085595
# 17965   3.176718 -3.963654 -3.424769
# 17966   3.209030 -0.047941 -2.952318
# 17967   6.712742  0.836563 -3.622096
# 17968   5.138618  0.304404 -3.991676
# 17969   6.062286  0.556744 -4.293474
# 17970   3.145026 -1.763672 -3.333211
# 17971   3.818871  0.333956 -3.181665
# 17972   4.111666  0.113135 -2.846003
# 17973   3.114329 -1.029276 -3.967092
# 17974   3.365894 -0.708689 -4.130554
# 17975   5.333661  0.148760 -3.717859
# 17976   6.615949  0.762664 -4.081078
# 17977   3.330091 -4.260655 -3.581282
# 17978   8.181692 -1.055593 -1.440865
# 17979   5.667923  0.670014 -3.174405
# 17980   3.406848 -2.908089 -1.745336
# 17981   3.847872 -0.285794 -3.122443
# 17982   4.026700 -1.577049 -4.030419
# 17983   5.676774 -0.240797 -4.323292
# 17984   3.733780 -1.520216 -4.047402
# 17985   6.614699  0.015145 -5.058913
# 17986  10.899711 -2.149089 -0.752045
# 17987   6.771349  0.267738 -4.848353
# 17988   4.730801 -0.706828 -1.709118
# 17989  11.389639 -2.807262 -0.706154
# 17990  10.664289 -1.432064 -0.690132
# 17991   3.954688 -3.370524 -3.474166
# 17992   3.582446 -0.692922 -4.046387
# 17993   8.291728  1.064018 -3.955568
#
# [17994 rows x 6 columns]

# %%
# Classifier using K-Means Results:
# Train on X_pca_train w/o 'Torwart'
#X_pca_new = X_pca.where(X_pca.index == y.where(y['Position']!='Torwart').index)
y_new = y.where(y['Position']!='Torwart').dropna()
y_new_index = y_new.index.tolist()
X_pca_new = X_pca.iloc[y_new_index,:]

X_new_train,X_new_test, y_new_train, y_new_test = train_test_split(X_pca_new,y_new, test_size=0.1)

svc_2 = SVC(kernel='rbf')
svc_2 = svc_2.fit(X_new_train,y_new_train)
y_pred_new = svc_2.predict(X_new_test)
print('Precision in sample :{}% \n Precision in test: {}%'.format(100*svc_pca.score(X_pca_train,y_pca_train),100*svc_pca.score(X_pca_test,y_pca_test)))
# Out:
# C:\Users\MartinDammrath\Anaconda3\lib\site-packages\sklearn\utils\validation.py:547: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Precision in sample :83.43831048536495%
#  Precision in test: 82.72222222222221%

# %%
print(classification_report(y_new_test, y_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#   Mittelfeld       0.67      0.55      0.60       427
#        Sturm       0.85      0.89      0.87       582
# Verteidigung       0.85      0.90      0.87       589
#
#  avg / total       0.80      0.81      0.80      1598

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure(figsize=(25,20))
ax = fig.gca(projection='3d')
#ax = fig.add_subplot(1, 1, 1, axisbg="white")
ax.scatter(k_means_stats_0[:,0], k_means_stats_0[:,1], k_means_stats_0[:,2],color='orange', label='Cluster 1',s=1)
ax.scatter(k_means_stats_1[:,0], k_means_stats_1[:,1], k_means_stats_1[:,2],color='cyan', label='Cluster 2',s=1)
ax.scatter(k_means_stats_2[:,0], k_means_stats_2[:,1], k_means_stats_2[:,2],color='purple', label='Cluster 3',s=1)
ax.scatter(k_means_stats_3[:,0], k_means_stats_3[:,1], k_means_stats_3[:,2],color='green', label='Cluster 4',s=1)
ax.scatter(k_means.cluster_centers_[:,0], k_means.cluster_centers_[:,1], k_means.cluster_centers_[:,2],color='red',marker='*',s=300, label='Zentrum')
ax.legend()
ax.grid(False)
ax.view_init(20, 45)
plt.savefig("KMeans.jpg",dpi=500)

plt.show()

# %%
# Out:
#            Position
# 0             Sturm
# 1             Sturm
# 2             Sturm
# 3             Sturm
# 4           Torwart
# 5             Sturm
# 6           Torwart
# 7             Sturm
# 8        Mittelfeld
# 9             Sturm
# 10     Verteidigung
# 11       Mittelfeld
# 12          Torwart
# 13            Sturm
# 14       Mittelfeld
# 15            Sturm
# 16            Sturm
# 17     Verteidigung
# 18          Torwart
# 19            Sturm
# 20          Torwart
# 21            Sturm
# 22       Mittelfeld
# 23            Sturm
# 24     Verteidigung
# 25     Verteidigung
# 26     Verteidigung
# 27     Verteidigung
# 28       Mittelfeld
# 29          Torwart
# ...             ...
# 17964         Sturm
# 17965         Sturm
# 17966    Mittelfeld
# 17967  Verteidigung
# 17968  Verteidigung
# 17969  Verteidigung
# 17970    Mittelfeld
# 17971    Mittelfeld
# 17972    Mittelfeld
# 17973    Mittelfeld
# 17974    Mittelfeld
# 17975  Verteidigung
# 17976  Verteidigung
# 17977         Sturm
# 17978       Torwart
# 17979  Verteidigung
# 17980         Sturm
# 17981  Verteidigung
# 17982         Sturm
# 17983  Verteidigung
# 17984         Sturm
# 17985  Verteidigung
# 17986       Torwart
# 17987  Verteidigung
# 17988    Mittelfeld
# 17989       Torwart
# 17990       Torwart
# 17991         Sturm
# 17992    Mittelfeld
# 17993  Verteidigung
#
# [17994 rows x 1 columns]

# %%
# for angle in range(0, 360):
#     ax.view_init(30, angle)
#     plt.draw()
#     plt.pause(.001)

# %%
# Achtung, faulerweise überschrieb 

# y_pred = svc.predict(X)
# y_pred = pd.DataFrame(y_pred)
# y_pred = pd.DataFrame(y_pred.values, index=y.index,columns=['Prediction'])
# y_pred_vs_test = y_pred.join(y, how="left")
# y_pred_vs_test = y_pred_vs_test.join(player_info, how='left')
# y_pred_vs_test = y_pred_vs_test.where(y_pred_vs_test['Prediction'] != y_pred_vs_test['Position'])
# y_pred_vs_test.dropna(inplace=True)
# y_pred_vs_test = y_pred_vs_test.drop(['index','Unnamed: 0'], axis=1)
# y_pred_vs_test = y_pred_vs_test.join(X['overall'])
# y_pred_vs_test.loc[y_pred_vs_test['league'] == 'German Bundesliga']

#missmatch_count = y_pred_vs_test.groupby(['club']).size().reset_index(name='counts')
#missmatch_count

# %%
# from sklearn.cluster import KMeans
# k_means = KMeans(n_clusters=4, random_state=0)
# k_means = k_means.fit(X_train)
# means_pos = pd.DataFrame(k_means.predict(X_train)).reindex(index=X_train.index).join(y_train)
# means_pos

# %%
# X_pca[:,0].tolist()
# X_pca = pd.DataFrame(X_pca, columns=['PC1','PC2']).reindex(index=X_train_modif.index)
# X_pca = X_pca.join(y, how='right')
# from matplotlib import pyplot as plt
# # plt.clf()
# # plt.plot(X_pca.iloc[:,0],X_pca.iloc[:,1], 'bo ')
# # plt.show()

# fig = plt.figure(figsize = (8,8))
# ax = fig.add_subplot(1,1,1) 
# ax.set_xlabel('Principal Component 1', fontsize = 15)
# ax.set_ylabel('Principal Component 2', fontsize = 15)
# ax.set_title('2 component PCA', fontsize = 20)
# targets = ['Torwart','Verteidigung','Mittelfeld','Sturm']
# colors = ['r', 'g', 'b','m']
# for target, color in zip(targets,colors):
#     indicesToKeep = X_pca['Position'] == target
#     ax.scatter(X_pca.loc[indicesToKeep, 'PC1']
#                , X_pca.loc[indicesToKeep, 'PC2']
#                , c = color
#                , s = 50)
# ax.legend(targets)
# ax.grid()
# plt.show()

# %%
# ind_of_no_match = []
# import numpy as np
# y_test_array = np.array(y_test)

# for i in range(0,len(y_pred)):
#     if not y_pred[i]==y_test_array[i,0]:
#         ind_of_no_match.append(i)
        
# ind_of_no_match
# player_info = pd.read_csv('player_info.csv', encoding = "ISO-8859-1")
# missmatches = []
# for i in ind_of_no_match:
#     missmatches.append([player_info.iloc[i,2],y_test_array[i,0],y_pred[i]])

# missmatches = pd.DataFrame(missmatches, columns=['Player_Name','Real_Pos','Predicted_Pos'])
# missmatches

# %%
# X_missmatched = []
# for i in ind_of_no_match:
#     X_missmatched.append(X.iloc[i,:])
# X_missmatched = pd.DataFrame(X_missmatched)
# X_missmatched

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components=3)
# pca_components = pca.fit_transform(X_train)
# principalDf = pd.DataFrame(data = pca_components, columns = ['principal component 1', 'principal component 2','principal component 3'])

# finalDf = pd.concat([principalDf, y], axis = 1)

# finalDf

# %%
# from matplotlib import pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D

# fig = plt.figure(figsize = (8,8))
# ax = fig.add_subplot(111, projection='3d')
# ax.set_xlabel('Principal Component 1', fontsize = 15)
# ax.set_ylabel('Principal Component 2', fontsize = 15)
# ax.set_zlabel('Principal Component 3', fontsize = 15)
# ax.set_title('3 component PCA', fontsize = 20)
# targets = ['Verteidigung','Sturm','Torwart','Mittelfeld']
# colors = ['r', 'g', 'b', 'm']
# for target, color in zip(targets,colors):
#     indicesToKeep = finalDf['Position'] == target
#     ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
#                , finalDf.loc[indicesToKeep, 'principal component 2']
#                , finalDf.loc[indicesToKeep, 'principal component 3']
#                , c = color
#                , s = 50)
# ax.legend(targets)
# ax.grid()



# ax.view_init(azim=250, elev=20)
# fig

# %%
# ax.view_init(azim=180, elev=20)
# fig
